# %%
# Verificador de tarea1.c

# --- valores de A y B (los que imprime printf de "A (high: ..., low: ...)") ---
A_high = 10193426843650594559
A_low  = 8003148000026208600
B_high = 14440657953798181851
B_low  = 6270588181487939435

# --- las 4 columnas del resultado (las que imprime "Resultado (col3 col2 col1 col0)") ---
col3 = 7979716628476088760
col2 = 2720942559943200543
col1 = 4370121281541529771
col0 = 15619055136910340040

# %%
# --- reconstruccion y verificacion
A = A_high * 2**64 + A_low
B = B_high * 2**64 + B_low
esperado = A * B
obtenido = col3 * 2**192 + col2 * 2**128 + col1 * 2**64 + col0

# %%
print("A        =", A)
print("B        =", B)
print("esperado =", esperado)
print("obtenido =", obtenido)
print("COINCIDE :", esperado == obtenido)
# Out:
# A        = 188035536218903465361652505515725465944
# B        = 266383121529693311091601760574726860651
# esperado = 50089493096501210083428171661800568394556517229472725797911820194769334169544
# obtenido = 50089493096501210083428171661800568394556517229472725797911820194769334169544
# COINCIDE : True
